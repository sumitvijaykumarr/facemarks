# %%
import pandas as pd
import numpy as np
import cv2 as cv

# %%
df = pd.read_csv('/content/drive/MyDrive/training (1).csv')

# %%
df.head()
# Out:
#    left_eye_center_x  ...                                              Image
# 0          66.033564  ...  238 236 237 238 240 240 239 241 241 243 240 23...
# 1          64.332936  ...  219 215 204 196 204 211 212 200 180 168 178 19...
# 2          65.057053  ...  144 142 159 180 188 188 184 180 167 132 84 59 ...
# 3          65.225739  ...  193 192 193 194 194 194 193 192 168 111 50 12 ...
# 4          66.725301  ...  147 148 160 196 215 214 216 217 219 220 206 18...
#
# [5 rows x 31 columns]

# %%
df["Image"]=df["Image"].apply(lambda i: np.fromstring(i, sep=' '))

# %%
df = df.dropna()

# %%
imgs_array = np.vstack(df['Image'].values)/ 255.0
imgs_array = imgs_array.astype(np.float32)
imgs_array = imgs_array.reshape(-1,96,96,1)

# %%
labels_array = df[df.columns[:-1]].values
labels_array = (labels_array-48)/48
labels_array = labels_array.astype(np.float)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, Activation
from keras.layers import Flatten, Dense
from keras.layers.normalization import batch_normalization 
from keras import optimizers
from keras.callbacks import ModelCheckpoint, History

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.7.0'

# %%
def the_model():
  model = Sequential()

  model.add(Conv2D(16, (3,3), padding='same', activation='relu', input_shape=X_train.shape[1:]))
  model.add(MaxPooling2D(pool_size=2))

  model.add(Conv2D(32, (3,3), padding='same', activation='relu'))
  model.add(MaxPooling2D(pool_size=2))

  model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
  model.add(MaxPooling2D(pool_size=2))

  model.add(Conv2D(128,(3,3), padding='same', activation='relu'))
  model.add(MaxPooling2D(pool_size=2))

  model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
  model.add(MaxPooling2D(pool_size=2))

  #Conert all values to 1D array
  model.add(Flatten())
  
  model.add(Dense(512, activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(30))
  return model

# %%
X_train = imgs_array
y_train = labels_array

# %%
epochs = 60
batch_size = 64
model = the_model()
hist = History()
checkpointer = ModelCheckpoint(filepath='checkpoint1.hdf5',
                               verbose=1, save_best_only=True)

# %%
#Compile Model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model_fit = model.fit(X_train, y_train, validation_split=0.2, epochs=epochs, batch_size=batch_size, callbacks=[checkpointer, hist], verbose=1)
model.save('model1.h5')
# Out:
# Epoch 1/60
# 27/27 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.4953
# Epoch 00001: val_loss improved from inf to 0.01324, saving model to checkpoint1.hdf5
# 27/27 [==============================] - 20s 711ms/step - loss: 0.0307 - accuracy: 0.4953 - val_loss: 0.0132 - val_accuracy: 0.4322
# Epoch 2/60
# 27/27 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.6437
# Epoch 00002: val_loss improved from 0.01324 to 0.00843, saving model to checkpoint1.hdf5
# 27/27 [==============================] - 19s 693ms/step - loss: 0.0091 - accuracy: 0.6437 - val_loss: 0.0084 - val_accuracy: 0.4322
# Epoch 3/60
# 27/27 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.6904
# Epoch 00003: val_loss improved from 0.00843 to 0.00817, saving model to checkpoint1.hdf5
# 27/27 [==============================] - 19s 692ms/step - loss: 0.0066 - accuracy: 0.6904 - val_loss: 0.0082 - val_accuracy: 0.4322
# Epoch 4/60
# ...
